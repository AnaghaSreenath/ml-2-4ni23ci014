# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaghaSreenath/ml-2-4ni23ci014/blob/main/ml2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

notebook_path = '/content/ML2_1.ipynb'


with open(notebook_path, 'r') as f:
    notebook_content = json.load(f)

print(f"\n--- Code from {notebook_path} ---\n")
for cell in notebook_content['cells']:
    if cell['cell_type'] == 'code':

        print(''.join(cell['source']))
        print('\n--- END OF CELL ---\n')
# Out:
# --- Code from /content/ML2_1.ipynb ---
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# --- END OF CELL ---
#
# df = pd.read_csv("/content/sample_data/student_data.csv")
#
# --- END OF CELL ---
#
# print(df)
#
# --- END OF CELL ---
#
# print(df.head())
#
# --- END OF CELL ---
#
# print(df.tail())
#
# --- END OF CELL ---
#
# df.shape
#
# --- END OF CELL ---
#
# df.columns
#
# --- END OF CELL ---
#
# df.dtypes
#
# --- END OF CELL ---
#
# df.isnull().sum()
#
# --- END OF CELL ---
#
# df = pd.read_csv("/content/sample_data/student_data.csv")
#
# --- END OF CELL ---
#
# df.isnull().sum()
#
# --- END OF CELL ---
#
# df.dropna(inplace=True)
#
# --- END OF CELL ---
#
# df.isnull().sum()
#
# --- END OF CELL ---
#
# df.shape
#
# --- END OF CELL ---
#
# df = pd.read_csv("/content/sample_data/student_data.csv")
#
# --- END OF CELL ---
#
# print(df)
#
# --- END OF CELL ---
#
# df['StudyHours'] = df['StudyHours'].fillna(df['StudyHours'].mean())
#
# ...
